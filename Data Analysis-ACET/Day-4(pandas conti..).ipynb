# %% [markdown]
# - Pandas
#     * datset reading
#     * datset indexing
#     * dataset filtering
#     * dataset sorting
#     * statistical Operations on Dataset
#     * Data set Cleaning
#     * dataset plotting
#     * dataset saving

# %%
import pandas as pd

# %% [markdown]
# ### DataSet reading in pandas:
#         - pd.read_csv('filename.csv')
#         - pad.read_excel('filename.xlsx')

# %%
data=pd.read_csv('bird.csv')
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %% [markdown]
# #### head()--->it reutrns top 5 records from the dataset

# %%
data.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %% [markdown]
# #### tail():
#         - it returns last five rows from the dataset

# %%
data.tail()
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 415   SO
# 416   SO
# 417   SO
# 418   SO
# 419   SO

# %% [markdown]
# #### sample():
#         - it returns random row at a time from the dataset

# %%
data.sample()
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 386  386  25.24  2.42  32.13    2.1  21.14  1.69  29.58  1.57  25.49  1.42
#
#     type
# 386   SO

# %%
### sample(length):

# %%
data.sample(10)
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 230  230   41.65   3.62   46.01   3.03  38.37  2.85   48.11  2.55  35.49
# 365  365   29.52   2.92   37.47   2.37  28.22  2.25   47.49  1.98  34.60
# 60    60  300.00  12.48  300.00   8.65  84.05  8.53  178.00  9.61  99.01
# 56    56  310.00  14.40  315.00   9.51  88.77  8.10  180.00  9.45  96.13
# 297  297   37.05   3.48   41.41   2.91  37.37  3.14   61.65  2.89  44.72
# 389  389   19.63   1.76   23.58   1.33  18.85  1.54   33.10  1.34  24.09
# 27    27   46.20   7.06   32.73   8.58  52.15  5.11   75.99  4.77  23.24
# 132  132   76.71   5.82   61.54   5.20  47.87  3.53   75.24  4.21  35.11
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 387  387   23.90   2.32   28.83   1.67  21.18  1.85   33.11  1.61  23.02
#
#       tarw type
# 230   2.22    R
# 365   1.63   SO
# 60    7.55   SW
# 56    7.69   SW
# 297   2.24   SO
# 389   1.14   SO
# 27   10.24   SW
# 132   4.47    W
# ...

# %% [markdown]
# ##### columns:
#         - it returns total column names from the dataset

# %%
data.columns
# Out:
# Index(['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %% [markdown]
# ##### columns[index]

# %%
data.columns[0]
# Out:
# 'id'

# %%
data.columns[11]
# Out:
# 'type'

# %%
data.columns[:3]
# Out:
# Index(['id', 'huml', 'humw'], dtype='object')

# %%
data.columns[::-1]
# Out:
# Index(['type', 'tarw', 'tarl', 'tibw', 'tibl', 'femw', 'feml', 'ulnaw',
#        'ulnal', 'humw', 'huml', 'id'],
#       dtype='object')

# %% [markdown]
# #### index():
#         - it returns total index of the dataset

# %%
data.index
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %%
data[['huml']]
# Out:
#       huml
# 0    80.78
# 1    88.91
# 2    79.97
# 3    77.65
# 4    62.80
# ..     ...
# 415  17.96
# 416  19.21
# 417  18.79
# 418  20.38
# 419  17.89
#
# [420 rows x 1 columns]

# %%
type(data[['huml']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['id','humw']]
# Out:
#       id  humw
# 0      0  6.68
# 1      1  6.63
# 2      2  6.37
# 3      3  5.70
# 4      4  4.84
# ..   ...   ...
# 415  415  1.63
# 416  416  1.64
# 417  417  1.63
# 418  418  1.78
# 419  419  1.44
#
# [420 rows x 2 columns]

# %%
data[['feml','femw','huml']]
# Out:
#       feml  femw   huml
# 0    41.81  3.70  80.78
# 1    47.04  4.30  88.91
# 2    43.07  3.90  79.97
# 3    40.04  3.52  77.65
# 4    33.95  2.72  62.80
# ..     ...   ...    ...
# 415  18.36  1.54  17.96
# 416  19.24  1.45  19.21
# 417  20.96  1.43  18.79
# 418  21.35  1.48  20.38
# 419  17.62  1.34  17.89
#
# [420 rows x 3 columns]

# %% [markdown]
# #### info():
#     - it returns total information of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      420 non-null    int64
#  1   huml    419 non-null    float64
#  2   humw    419 non-null    float64
#  3   ulnal   417 non-null    float64
#  4   ulnaw   418 non-null    float64
#  5   feml    418 non-null    float64
#  6   femw    419 non-null    float64
#  7   tibl    418 non-null    float64
#  8   tibw    419 non-null    float64
#  9   tarl    419 non-null    float64
#  10  tarw    419 non-null    float64
#  11  type    420 non-null    object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 39.5+ KB

# %% [markdown]
# #### Describe():
#         - it describes the total dataset information

# %%
data.describe()
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw
# count  419.000000  418.000000  419.000000  419.000000  419.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024
# std      2.023581   37.838145    2.080827   23.184313    2.185673
# ...

# %% [markdown]
# #### datset indexing
#         - loc(location)
#                 - it takes both int and non-integer index values
#         -iloc(integer location)
#                 - it takes only integer index values

# %%
data[55:60]
# Out:
#     id    huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl  \
# 55  55   28.98   2.74   36.37   2.29   28.41  2.49   50.89   2.19   32.07
# 56  56  310.00  14.40  315.00   9.51   88.77  8.10  180.00   9.45   96.13
# 57  57  250.00  11.91  252.00   8.31   73.04  7.37  160.00   8.47   82.46
# 58  58  420.00  17.84  422.00  11.72  110.54  9.99  237.00  11.03  128.35
# 59  59  250.00  11.28  247.50   7.50   69.04  6.20  156.00   7.19   83.36
#
#     tarw type
# 55  2.03   SW
# 56  7.69   SW
# 57  7.04   SW
# 58  8.93   SW
# 59  6.13   SW

# %%
data[1:100:2]
# Out:
#     id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl   tarw  \
# 1    1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50   4.01
# 3    3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78   3.41
# 5    5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07   2.83
# 7    7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94   3.81
# 9    9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67   6.34
# 11  11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80   4.59
# 13  13  148.91   6.78  121.35   6.50  44.29  6.33  155.00  6.68  73.71   4.24
# 15  15  140.59   6.59  115.97   5.81  39.75  5.61  166.00  7.83  74.86   3.52
# 17  17  124.53   6.01  100.37   5.82  34.54  5.43  145.00  7.12  65.92   3.28
# 19  19  106.02   4.47   95.79   4.33  41.96  4.80  129.59  6.94  70.29   3.35
# 21  21  108.62   5.04   97.70   4.66  45.08  5.78  128.00  7.14  65.48   4.25
# ...

# %%
data.iloc[[100]]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 100  100  67.06  3.54  67.98   3.24  24.82  1.77  51.88  1.86  30.11  1.63
#
#     type
# 100   SW

# %%
data.loc[[100]]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 100  100  67.06  3.54  67.98   3.24  24.82  1.77  51.88  1.86  30.11  1.63
#
#     type
# 100   SW

# %%
data.iloc[100:200]
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 100  100   67.06  3.54   67.98   3.24  24.82  1.77   51.88  1.86  30.11  1.63
# 101  101   67.59  3.73   68.55   3.19  24.46  1.89   50.06  2.36  27.21  1.77
# 102  102  100.27  5.75  107.95   4.86  35.50  3.03   69.54  3.21  39.83  3.28
# 103  103   68.50  3.77   71.15   3.34  24.86  1.95   51.44  2.10  30.13  2.37
# 104  104   68.15  3.84   72.31   3.42  24.23  1.90   50.26  2.13  29.16  2.05
# ..   ...     ...   ...     ...    ...    ...   ...     ...   ...    ...   ...
# 195  195   34.63  3.10   26.87   2.35  40.87  3.05   53.98  2.79  31.59  2.63
# 196  196   32.28  3.34   28.79   2.45  38.46  2.82   52.93  2.50  30.97  2.48
# 197  197   92.82  9.60  100.58   7.57  82.94  7.47  118.24  6.61  69.16  5.66
# 198  198   55.62  4.79   52.09   4.26  64.80  5.74   86.17  4.76  49.37  4.25
# 199  199   32.68  3.26   29.02   2.36  39.38  2.72   56.45  2.50  32.56  2.49
#
#     type
# 100   SW
# 101   SW
# ...

# %%
data.loc[100:200:2]
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw    tarl  \
# 100  100   67.06  3.54   67.98   3.24  24.82  1.77   51.88  1.86   30.11
# 102  102  100.27  5.75  107.95   4.86  35.50  3.03   69.54  3.21   39.83
# 104  104   68.15  3.84   72.31   3.42  24.23  1.90   50.26  2.13   29.16
# 106  106  109.70  4.65  109.87   4.04  35.16  3.25   76.80  3.56   47.27
# 108  108  100.08  5.07  100.81   4.04  37.15  3.77   87.55  3.96   52.91
# 110  110   75.95  5.42   66.16   4.16  30.71  3.10   78.94  3.56   44.82
# 112  112  105.19  7.10   96.85   5.43  37.61  4.43  102.04  4.90   54.78
# 114  114   65.66  3.79   61.06   3.35  24.95  2.44   63.76  2.72   40.19
# 116  116  157.00  9.00  192.00   7.02  85.60  6.44  227.00  6.84  175.00
# 118  118   70.01  3.71   76.90   2.88  49.42  3.08   79.56  3.35   52.74
# 120  120  118.52  6.87  134.91   5.06  78.20  5.24  132.00  5.38   85.28
# 122  122   67.63  4.37   60.17   3.73  53.03  4.08   92.18  4.31   54.38
# ...

# %%
data.loc[100,'humw']
# Out:
# 3.54

# %%
data.iloc[[100]]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 100  100  67.06  3.54  67.98   3.24  24.82  1.77  51.88  1.86  30.11  1.63
#
#     type
# 100   SW

# %%
data.iloc[200,[2]]
# Out:
# humw    3.39
# Name: 200, dtype: object

# %%
data.loc[200:300,['tibl','tarl','tarw']]  # row index,column names
# Out:
#        tibl    tarl  tarw
# 200   53.77   32.24  2.67
# 201  183.00  134.00  7.96
# 202  189.00  128.50  8.19
# 203   64.45   37.77  2.86
# 204   75.67   60.19  3.82
# ..      ...     ...   ...
# 296   53.96   42.71  2.41
# 297   61.65   44.72  2.24
# 298   64.68   46.74  2.54
# 299   62.45   46.41  2.42
# 300   64.97   47.69  2.57
#
# [101 rows x 3 columns]

# %%
data.iloc[100:120]
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl  tibw    tarl  \
# 100  100   67.06   3.54   67.98   3.24   24.82  1.77   51.88  1.86   30.11
# 101  101   67.59   3.73   68.55   3.19   24.46  1.89   50.06  2.36   27.21
# 102  102  100.27   5.75  107.95   4.86   35.50  3.03   69.54  3.21   39.83
# 103  103   68.50   3.77   71.15   3.34   24.86  1.95   51.44  2.10   30.13
# 104  104   68.15   3.84   72.31   3.42   24.23  1.90   50.26  2.13   29.16
# 105  105  107.76   4.71  110.21   4.12   36.15  3.11   76.18  3.77   49.61
# 106  106  109.70   4.65  109.87   4.04   35.16  3.25   76.80  3.56   47.27
# 107  107  100.69   4.80  101.28   4.13   36.36  3.36   85.62  4.20   52.54
# 108  108  100.08   5.07  100.81   4.04   37.15  3.77   87.55  3.96   52.91
# 109  109   70.04   4.74   61.26   3.97   28.12  2.98   71.11  3.44   40.23
# 110  110   75.95   5.42   66.16   4.16   30.71  3.10   78.94  3.56   44.82
# ...

# %%
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data.iloc[200:205,0:3]  # row index,column index
# Out:
#       id    huml   humw
# 200  200   34.24   3.39
# 201  201  118.75  11.90
# 202  202  127.00  13.79
# 203  203   39.64   4.07
# 204  204   63.76   4.74

# %%
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %% [markdown]
# ### How set index in dataset:
#         - pd.set_index('column name')

# %%
bird=data.set_index('type')
bird
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [420 rows x 11 columns]

# %%
bird.head()
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW     0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW     1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW     2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW     3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW     4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13

# %%
bird.tail()
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05

# %%
bird.loc[['SW','SO']]
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [244 rows x 11 columns]

# %% [markdown]
# ### How to reset the index in dataset
#         - dataset_variable name.reset_index()

# %%
bird1=bird.reset_index()
bird1
# Out:
#     type   id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  \
# 0     SW    0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70
# 1     SW    1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50
# 2     SW    2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31
# 3     SW    3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78
# 4     SW    4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88
# ..   ...  ...    ...   ...    ...    ...    ...   ...    ...   ...    ...
# 415   SO  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99
# 416   SO  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60
# 417   SO  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86
# 418   SO  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98
# 419   SO  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69
#
#      tarw
# 0    3.84
# 1    4.01
# 2    3.34
# 3    3.41
# 4    3.13
# ...

# %%
bird1.head()
# Out:
#   type  id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# 0   SW   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1   SW   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2   SW   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3   SW   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4   SW   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13

# %%
bird1.iloc[[100]]
# Out:
#     type   id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  \
# 100   SW  100  67.06  3.54  67.98   3.24  24.82  1.77  51.88  1.86  30.11
#
#      tarw
# 100  1.63

# %%
bird1.loc[120,'huml']
# Out:
# 118.52

# %% [markdown]
# #### dataset filtering

# %%
data.count()
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# type     420
# dtype: int64

# %%
data['huml'].min()
# Out:
# 9.85

# %%
data['huml'].max()
# Out:
# 420.0

# %%
data[data['ulnal'] > 90]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# 12    12  172.00   8.44  142.00   8.43  52.18  6.68  180.00  9.62  82.58
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type
# 8    4.37   SW
# 9    6.34   SW
# 10   6.63   SW
# 11   4.59   SW
# ...

# %%
data[data['ulnal'] > 90].shape
# Out:
# (122, 12)

# %%
data.shape
# Out:
# (420, 12)

# %%
data[(data['huml'] > 90) & (data['huml'] < 150)]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 13    13  148.91   6.78  121.35   6.50  44.29  6.33  155.00  6.68  73.71
# 14    14  149.19   6.98  121.48   6.21  43.33  5.39  155.00  6.61  75.65
# 15    15  140.59   6.59  115.97   5.81  39.75  5.61  166.00  7.83  74.86
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type
# 8    4.37   SW
# 9    6.34   SW
# 13   4.24   SW
# 14   3.36   SW
# ...

# %%
data[(data['huml'] > 90) & (data['huml'] < 150)].shape
# Out:
# (78, 12)

# %%
data[data['type'] == "SO"]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 292  292  29.61  2.41  33.93   2.02  30.79  2.19  51.64  2.01  37.33  1.78
# 293  293  30.28  2.89  35.37   2.15  31.09  2.51  53.36  2.31  39.52  1.69
# 294  294  28.10  2.44  32.50   2.19  29.68  2.33  50.47  2.21  37.98  1.79
# 295  295  28.66  2.48  33.24   2.02  29.33  2.26  50.64  2.05  35.99  1.85
# 296  296  36.36  3.31  40.51   2.56  37.52  2.85  53.96  2.63  42.71  2.41
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 292   SO
# 293   SO
# 294   SO
# 295   SO
# 296   SO
# ...

# %%
data[(data['type'] =="P") | (data['type'] =="SW")]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 287  287  27.72  2.67  32.00   2.21  22.68  2.13  32.50  1.76  19.65  1.64
# 288  288  29.14  2.75  32.91   2.16  23.13  2.11  33.89  1.80  20.86  1.70
# 289  289  27.85  2.65  32.62   2.05  22.84  2.14  33.62  1.91  20.82  1.80
# 290  290  20.06  1.73  23.15   1.49  16.63  1.57  24.71  1.29  15.19  1.24
# 291  291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data[(data['type'] =="P") | (data['type'] =="SW")].shape
# Out:
# (154, 12)

# %%
data[data['type'] == "SW"].any(axis=1)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 111    True
# 112    True
# 113    True
# 114    True
# 115    True
# Length: 116, dtype: bool

# %%
data[data['type'] == "SO"].all(axis=0)
# Out:
# id       True
# huml     True
# humw     True
# ulnal    True
# ulnaw    True
# feml     True
# femw     True
# tibl     True
# tibw     True
# tarl     True
# tarw     True
# type     True
# dtype: bool

# %% [markdown]
# #### Dataset sorting
#     - pd.sort_index()--->ascending order)
#     - pd.sort_index(ascending=False)--->descending order

# %%
#### row index numbers

# %%
data.sort_index()
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data.sort_index(ascending=False)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
#
#     type
# 419   SO
# 418   SO
# 417   SO
# 416   SO
# 415   SO
# ...

# %%
data.sort_index(axis=0,ascending=True)   # row index numbers in ascending order
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data.sort_index(axis=0,ascending=False)  # row index numbers in descending order
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
#
#     type
# 419   SO
# 418   SO
# 417   SO
# 416   SO
# 415   SO
# ...

# %% [markdown]
# ##### column names

# %%
data.sort_index(axis=1,ascending=True)   ### column names in ascending order
# Out:
#       feml  femw   huml  humw   id   tarl  tarw   tibl  tibw type  ulnal  \
# 0    41.81  3.70  80.78  6.68    0  38.70  3.84   5.50  4.03   SW  72.01
# 1    47.04  4.30  88.91  6.63    1  41.50  4.01  80.22  4.51   SW  80.53
# 2    43.07  3.90  79.97  6.37    2  38.31  3.34  75.35  4.04   SW  69.26
# 3    40.04  3.52  77.65  5.70    3  35.78  3.41  69.17  3.40   SW  65.76
# 4    33.95  2.72  62.80  4.84    4  31.88  3.13  56.27  2.96   SW  52.09
# ..     ...   ...    ...   ...  ...    ...   ...    ...   ...  ...    ...
# 415  18.36  1.54  17.96  1.63  415  21.99  1.15  31.25  1.33   SO  19.25
# 416  19.24  1.45  19.21  1.64  416  23.60  1.15  33.21  1.28   SO  20.76
# 417  20.96  1.43  18.79  1.63  417  22.86  1.21  34.45  1.41   SO  19.83
# 418  21.35  1.48  20.38  1.78  418  25.98  1.24  36.09  1.53   SO  22.53
# 419  17.62  1.34  17.89  1.44  419  21.69  1.05  29.81  1.24   SO  19.26
#
#      ulnaw
# 0     4.88
# 1     5.59
# 2     5.28
# 3     4.77
# 4     3.73
# ..     ...
# ...

# %%
data.sort_index(axis=1,ascending=False) ### column names in descending order
# Out:
#      ulnaw  ulnal type  tibw   tibl  tarw   tarl   id  humw   huml  femw  \
# 0     4.88  72.01   SW  4.03   5.50  3.84  38.70    0  6.68  80.78  3.70
# 1     5.59  80.53   SW  4.51  80.22  4.01  41.50    1  6.63  88.91  4.30
# 2     5.28  69.26   SW  4.04  75.35  3.34  38.31    2  6.37  79.97  3.90
# 3     4.77  65.76   SW  3.40  69.17  3.41  35.78    3  5.70  77.65  3.52
# 4     3.73  52.09   SW  2.96  56.27  3.13  31.88    4  4.84  62.80  2.72
# ..     ...    ...  ...   ...    ...   ...    ...  ...   ...    ...   ...
# 415   1.33  19.25   SO  1.33  31.25  1.15  21.99  415  1.63  17.96  1.54
# 416   1.49  20.76   SO  1.28  33.21  1.15  23.60  416  1.64  19.21  1.45
# 417   1.53  19.83   SO  1.41  34.45  1.21  22.86  417  1.63  18.79  1.43
# 418   1.50  22.53   SO  1.53  36.09  1.24  25.98  418  1.78  20.38  1.48
# 419   1.10  19.26   SO  1.24  29.81  1.05  21.69  419  1.44  17.89  1.34
#
#       feml
# 0    41.81
# 1    47.04
# 2    43.07
# 3    40.04
# 4    33.95
# ..     ...
# ...

# %% [markdown]
# #### column values:
#         - pd.sort_values(by='column name')

# %%
data.sort_values(by='huml',ascending=True)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl  \
# 264  264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77
# 377  377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97
# 413  413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19
# 367  367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97
# 370  370   13.38   1.14   16.51   1.23   12.48  1.12   24.91   0.92   17.55
# ..   ...     ...    ...     ...    ...     ...   ...     ...    ...     ...
# 38    38  272.00  14.86  320.00  10.42   91.60  9.71  132.00  10.23   81.77
# 60    60  300.00  12.48  300.00   8.65   84.05  8.53  178.00   9.61   99.01
# 56    56  310.00  14.40  315.00   9.51   88.77  8.10  180.00   9.45   96.13
# 58    58  420.00  17.84  422.00  11.72  110.54  9.99  237.00  11.03  128.35
# 342  342     NaN    NaN     NaN    NaN   32.54  2.65   55.06   2.81   38.94
#
#      tarw type
# 264  1.23    P
# 377  0.66   SO
# ...

# %%
data.sort_values(by='feml',ascending=False)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml   femw    tibl   tibw    tarl  \
# 202  202  127.00  13.79  123.27   9.42  117.07  11.64  189.00  10.03  128.50
# 58    58  420.00  17.84  422.00  11.72  110.54   9.99  237.00  11.03  128.35
# 201  201  118.75  11.90  104.68   4.77  108.85  10.29  183.00   9.69  134.00
# 117  117  190.00  11.92  225.00   8.55  101.75   7.75  240.00   7.71  175.00
# 221  221  130.06   9.51  155.00   7.18   94.79   8.64  125.53   7.87   53.83
# ..   ...     ...    ...     ...    ...     ...    ...     ...    ...     ...
# 367  367   13.31   1.17   16.47   1.06   12.32   0.93   22.47   0.95   15.97
# 70    70   26.63   1.63   27.19   1.72   12.21   1.02   31.56   1.07   21.62
# 377  377   12.69   1.69   17.44   1.16   11.83   1.03   23.80   0.87   16.97
# 160  160   76.43   4.11   86.79   3.84     NaN    NaN   67.13   2.48   41.65
# 404  404   20.36   1.87   22.19   1.60     NaN   1.77   37.47   1.64   25.54
#
#      tarw type
# 202  8.19    T
# ...

# %% [markdown]
# ### Statistical Operations on Dataset

# %%
data.sum()
# Out:
# id                                                   87990
# huml                                              27088.56
# humw                                               1831.27
# ulnal                                             28821.11
# ulnaw                                              1503.65
# feml                                              15412.67
# femw                                               1349.55
# tibl                                              27029.06
# tibw                                                1333.4
# tarl                                              16437.36
# tarw                                               1227.68
# type     SWSWSWSWSWSWSWSWSWSWSWSWSWSWSWSWSWSWSWSWSWSWSW...
# dtype: object

# %%
data['huml'].sum()
# Out:
# 27088.56

# %%
data[['feml','femw']].sum()
# Out:
# feml    15412.67
# femw     1349.55
# dtype: float64

# %%
data['feml'].mean()
# Out:
# 36.87241626794258

# %%
data[['huml','humw']].mean()
# Out:
# huml    64.650501
# humw     4.370573
# dtype: float64

# %%
data['ulnal'].median()
# Out:
# 43.71

# %%
data[['huml','ulnal']].median()
# Out:
# huml     44.18
# ulnal    43.71
# dtype: float64

# %%
data['huml'].mode()
# Out:
# 0    145.0
# Name: huml, dtype: float64

# %%
data['huml'].value_counts()
# Out:
# huml
# 145.00    3
# 22.26     2
# 175.00    2
# 32.31     2
# 150.00    2
#          ..
# 44.71     1
# 50.22     1
# 45.18     1
# 45.68     1
# 17.89     1
# Name: count, Length: 407, dtype: int64

# %%
data['tibl'].max()
# Out:
# 240.0

# %%
data['tibl'].min()
# Out:
# 5.5

# %%
data['huml'].argmax()
# Out:
# 58

# %%
data['huml'].idxmax()
# Out:
# 58

# %%
data.iloc[[58]]
# Out:
#     id   huml   humw  ulnal  ulnaw    feml  femw   tibl   tibw    tarl  tarw  \
# 58  58  420.0  17.84  422.0  11.72  110.54  9.99  237.0  11.03  128.35  8.93
#
#    type
# 58   SW

# %%
data['huml'].argmin()
# Out:
# 264

# %%
data.iloc[[264]]
# Out:
#       id  huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw  tarl  tarw type
# 264  264  9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25  7.77  1.23    P

# %%
import numpy as np

# %%
data['ulnal'].agg([np.min,np.max,np.sum,np.mean,np.median,np.std,np.var])
# Out:
# amin         14.090000
# amax        422.000000
# sum       28821.110000
# mean         69.115372
# median       43.710000
# std          58.784775
# var        3455.649766
# Name: ulnal, dtype: float64

# %% [markdown]
# #### Data Cleaning
#         - pd.read_csv('titanic.csv')

# %%
titanic=pd.read_csv('titanic.csv')
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
titanic.shape
# Out:
# (891, 11)

# %%
titanic.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
titanic.iloc[[150]]
# Out:
#      survived  pclass                        name   sex   age  sibsp  parch  \
# 150         0       2  Bateman, Rev. Robert James  male  51.0      0      0
#
#           ticket    fare cabin embarked
# 150  S.O.P. 1166  12.525   NaN        S

# %%
titanic.iloc[200:500,2:5]
# Out:
#                                                 name     sex   age
# 200                   Vande Walle, Mr. Nestor Cyriel    male  28.0
# 201                              Sage, Mr. Frederick    male   NaN
# 202                       Johanson, Mr. Jakob Alfred    male  34.0
# 203                             Youseff, Mr. Gerious    male  45.5
# 204                         Cohen, Mr. Gurshon "Gus"    male  18.0
# ..                                               ...     ...   ...
# 495                            Yousseff, Mr. Gerious    male   NaN
# 496                   Eustis, Miss. Elizabeth Mussey  female  54.0
# 497                  Shellard, Mr. Frederick William    male   NaN
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 499                               Svensson, Mr. Olof    male  24.0
#
# [300 rows x 3 columns]

# %% [markdown]
# #### cleaning the data:
#         - isnull()
#                 - Nan---> not a number
#         - notnull()
#         - dropna()
#         - fillna()

# %%
### isnull()--->T,F
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
titanic.isnull()
# Out:
#      survived  pclass   name    sex    age  sibsp  parch  ticket   fare  \
# 0       False   False  False  False  False  False  False   False  False
# 1       False   False  False  False  False  False  False   False  False
# 2       False   False  False  False  False  False  False   False  False
# 3       False   False  False  False  False  False  False   False  False
# 4       False   False  False  False  False  False  False   False  False
# ..        ...     ...    ...    ...    ...    ...    ...     ...    ...
# 886     False   False  False  False  False  False  False   False  False
# 887     False   False  False  False  False  False  False   False  False
# 888     False   False  False  False   True  False  False   False  False
# 889     False   False  False  False  False  False  False   False  False
# 890     False   False  False  False  False  False  False   False  False
#
#      cabin  embarked
# 0     True     False
# 1    False     False
# 2     True     False
# ...

# %%
#### notnull()---->T,F
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
titanic.notnull()
# Out:
#      survived  pclass  name   sex    age  sibsp  parch  ticket  fare  cabin  \
# 0        True    True  True  True   True   True   True    True  True  False
# 1        True    True  True  True   True   True   True    True  True   True
# 2        True    True  True  True   True   True   True    True  True  False
# 3        True    True  True  True   True   True   True    True  True   True
# 4        True    True  True  True   True   True   True    True  True  False
# ..        ...     ...   ...   ...    ...    ...    ...     ...   ...    ...
# 886      True    True  True  True   True   True   True    True  True  False
# 887      True    True  True  True   True   True   True    True  True   True
# 888      True    True  True  True  False   True   True    True  True  False
# 889      True    True  True  True   True   True   True    True  True   True
# 890      True    True  True  True   True   True   True    True  True  False
#
#      embarked
# 0        True
# 1        True
# ...

# %% [markdown]
# #### dropna()
#         - it removes Nan values from the dataset
#         - syntax:
#                 dataset variable_dropna()

# %%
titanic.shape
# Out:
# (891, 11)

# %%
drop=titanic.dropna()
drop
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                            McCarthy, Mr. Timothy J
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ..        ...     ...                                                ...
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                           Carlsson, Mr. Frans Olof
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         sex   age  sibsp  parch    ticket     fare        cabin embarked
# ...

# %%
drop.shape
# Out:
# (183, 11)

# %% [markdown]
# #### fillna()

# %%
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
fill=titanic.fillna(50)
fill
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %% [markdown]
# #### How to change column names in the dataset
#             - dataset_variable name.rename(columns={'old column name':'new column name'})

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
update_column=titanic.rename(columns={'pclass':'passager class'})
update_column
# Out:
#      survived  passager class  \
# 0           0               3
# 1           1               1
# 2           1               3
# 3           1               1
# 4           0               3
# ..        ...             ...
# 886         0               2
# 887         1               1
# 888         0               3
# 889         1               1
# 890         0               3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### dataset plotting

# %%
import matplotlib.pyplot as plt

# %%
data.plot()
plt.show()

# %%
titanic.plot()
plt.show()

# %% [markdown]
# #### DataSet Saving:
#         - pd.to_csv('filename.csv')
#         - pd.to_excel('filename.xlsx')

# %%
s_data=data.describe()
s_data.to_csv("birds_descript.csv")

# %%
s_data.to_excel("bird_description.xlsx")
